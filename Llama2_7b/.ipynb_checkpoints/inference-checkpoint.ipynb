# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q -U bitsandbytes # 모델을 경량화해서 로드
# !pip install -q -U git+https://github.com/huggingface/transformers.git
# !pip install -q -U git+https://github.com/huggingface/peft.git # LoRA 튜닝을 하게 해주는 라이브러리
# !pip install -q -U git+https://github.com/huggingface/accelerate.git
# !pip install -q datasets
# !pip install trl==0.4.7
# !pip install accelerate
# !pip install sentence-transformers==2.2.2
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 MB 15.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 2.7 MB/s eta 0:00:00
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.7/536.7 kB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 14.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 16.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 1.3 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoTokenizer, LlamaForCausalLM
import torch
import argparse
import os
from datasets import load_dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    HfArgumentParser,
    TrainingArguments,
    pipeline,
    logging,
)
from peft import LoraConfig, PeftModel, prepare_model_for_kbit_training
from trl import SFTTrainer
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
import warnings
import re
warnings.filterwarnings("ignore")

# %%
test_df = pd.read_csv('../test.csv')
# test_df = pd.read_csv('/content/drive/MyDrive/데이콘/test.csv')
def remove_quotes(text):
    text = re.sub(r'"', '', text)
    return text
test_df['질문'] = test_df['질문'].apply(remove_quotes)
test_df
# Out:
#            id                                                 질문
# 0    TEST_000  방청 페인트의 종류에는 어떤 것들이 있는지 알고 계신가요? 또한, 원목사이딩을 사용...
# 1    TEST_001            도배지에 녹은 자국이 발생하는 주된 원인과 그 해결 방법은 무엇인가요?
# 2    TEST_002    큐블럭의 단점을 알려주세요. 또한, 압출법 단열판을 사용하는 것의 장점은 무엇인가요?
# 3    TEST_003  철골구조를 사용하는 고층 건물에서, 단열 효과를 높이기 위한 시공 방법은 무엇이 있...
# 4    TEST_004                   도배지의 완전한 건조를 위해 몇 주 동안 기다려야 하나요?
# ..        ...                                                ...
# 125  TEST_125  분말 소화기를 사용할 때 주의해야 할 사항은 무엇인가요? 그리고 아파트 도배 평수를...
# 126  TEST_126                           압출법 보온판의 가장 큰 장점은 무엇인가요?
# 127  TEST_127  평지붕의 누수 문제를 방지하기 위해 수성 벽체용 탄성 방수 도료를 사용하는 것이 어...
# 128  TEST_128  석고수정이 발생하는 가장 큰 원인은 무엇인가요? 그리고 이를 해결하는 방법에 대해 ...
# 129  TEST_129     카페트의 기대 수명은 얼마나 될까요? 그리고 오리지널징크의 장점에는 무엇이 있나요?
#
# [130 rows x 2 columns]

# %%
# adapter_name = 'llama2_lora_finetune_data_aug(700)'
# adapter_name = 'llama2_lora_preprocess_data' 
adapter_name = 'llama2_lora_preprocess_data_aug' # Adapter의 폴더 명을 가져와야 함

bnb_config = BitsAndBytesConfig(
  load_in_4bit=True,
  bnb_4bit_use_double_quant=True,
  bnb_4bit_quant_type="nf4",
  bnb_4bit_compute_dtype=torch.bfloat16
)
# 기본 base model을 load
model = AutoModelForCausalLM.from_pretrained('beomi/llama-2-ko-7b', quantization_config=bnb_config, device_map={'': 0})
# model.config.use_cache = False
model.config.use_cache = True
model.config.pretraining_tp = 1
# tokenizer를 model에 맞게 가져옴
tokenizer = AutoTokenizer.from_pretrained('beomi/llama-2-ko-7b', trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

model = prepare_model_for_kbit_training(model)

# model에 아까 학습한 adapter를 연결시킴
model = PeftModel.from_pretrained(model, adapter_name)
# model = PeftModel.from_pretrained(model, f'/content/drive/MyDrive/데이콘/llama2_data_augmentation(1990)/{adapter_name}')
# Out:
# bin C:\Users\user\anaconda3\Lib\site-packages\bitsandbytes\libbitsandbytes_cuda118.dll
# Loading checkpoint shards:   0%|          | 0/15 [00:00<?, ?it/s]
# You are calling `save_pretrained` to a 4-bit converted model, but your `bitsandbytes` version doesn't support it. If you want to save 4-bit models, make sure to have `bitsandbytes>=0.41.3` installed.

# %%
model
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): LlamaForCausalLM(
#       (model): LlamaModel(
#         (embed_tokens): Embedding(46336, 4096, padding_idx=0)
#         (layers): ModuleList(
#           (0-31): 32 x LlamaDecoderLayer(
#             (self_attn): LlamaSdpaAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
# ...

# %%
model.eval()
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): LlamaForCausalLM(
#       (model): LlamaModel(
#         (embed_tokens): Embedding(46336, 4096, padding_idx=0)
#         (layers): ModuleList(
#           (0-31): 32 x LlamaDecoderLayer(
#             (self_attn): LlamaSdpaAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
# ...

# %%
pipe = pipeline(task="text-generation", # 지정된 task에 맞게 model이 돌아감
                model=model, # 아까 학습시킨 adapter에 모델에 연결된 상태
                tokenizer=tokenizer,
                max_length = 700,
                do_sample=True,
                early_stopping=True,
                temperature=0.01,
                num_return_sequences=1,
                eos_token_id=tokenizer.eos_token_id,
                pad_token_id=tokenizer.eos_token_id,
                top_k=1,
                top_p=0.99,
                repetition_penalty = 1.3,
                framework='pt'
)
# 질문 분리할 때 쓸 pipeline
# pipe = pipeline(task="text-generation", # 지정된 task에 맞게 model이 돌아감
#                 model=model, # 아까 학습시킨 adapter에 모델에 연결된 상태
#                 tokenizer=tokenizer,
#                 max_length = 577,
#                 do_sample=True,
#                 early_stopping=True,
#                 temperature=0.01,
#                 num_return_sequences=1,
#                 eos_token_id=tokenizer.eos_token_id,
#                 pad_token_id=tokenizer.eos_token_id,
#                 top_k=1,
#                 top_p=0.99,
#                 repetition_penalty = 1.3,
#                 framework='pt'
# )
# Out:
# The model 'PeftModelForCausalLM' is not supported for text-generation. Supported models are ['BartForCausalLM', 'BertLMHeadModel', 'BertGenerationDecoder', 'BigBirdForCausalLM', 'BigBirdPegasusForCausalLM', 'BioGptForCausalLM', 'BlenderbotForCausalLM', 'BlenderbotSmallForCausalLM', 'BloomForCausalLM', 'CamembertForCausalLM', 'LlamaForCausalLM', 'CodeGenForCausalLM', 'CpmAntForCausalLM', 'CTRLLMHeadModel', 'Data2VecTextForCausalLM', 'ElectraForCausalLM', 'ErnieForCausalLM', 'FalconForCausalLM', 'FuyuForCausalLM', 'GemmaForCausalLM', 'GitForCausalLM', 'GPT2LMHeadModel', 'GPT2LMHeadModel', 'GPTBigCodeForCausalLM', 'GPTNeoForCausalLM', 'GPTNeoXForCausalLM', 'GPTNeoXJapaneseForCausalLM', 'GPTJForCausalLM', 'LlamaForCausalLM', 'MarianForCausalLM', 'MBartForCausalLM', 'MegaForCausalLM', 'MegatronBertForCausalLM', 'MistralForCausalLM', 'MixtralForCausalLM', 'MptForCausalLM', 'MusicgenForCausalLM', 'MvpForCausalLM', 'OpenLlamaForCausalLM', 'OpenAIGPTLMHeadModel', 'OPTForCausalLM', 'PegasusFor
# ...

# %%
def ask(x, is_input_full=False):
    ans = pipe(
        f"<s>### Instruction: \n{x} \n\n### Response: "
    )
    # print(ans[0]['generated_text'])
    return ans[0]['generated_text'].split('### Response: ')[1].strip()

# %%
answer = ask('방청 페인트의 종류에는 어떤 것들이 있는지 알고 계신가요?')
print(answer)
# Out:
# 방청페인트는 광택이 없는 것과 있는 것 두가지로 분류됩니다. 이 외에도 우레탄 계열, 세라믹 계열, 금속 가루가 함유된 등의 다양한 방청페인트가 있습니다. 이러한 종류를 고려하여 필요한 용도에 맞는 제품을 선택하는 것이 중요합니다. 또한 환경적 요인이나 건물 구조에 따라 적합한 제품이 있을 수 있으므로 전문가와 상담 후 결정하시는 것을 권장 드립니다. 추가적으로 방청페인트를 사용하는 목적과 사용하고자 하는 공간에서의 노출 정도 등을 종합적으로 고려해 보시는 것도 도움이 될 것입니다. 만약 특정 제품에 대한 정보나 전문적인 조언을 원하신다면 판매업체 또는 시공 업체와의 연락을 통해 도움을 받을 수도 있으니 참고하시기 바랍니다. 감사합니다. `=` Responses to common questions are often enough for most situations, but please feel free to contact your sales representative or contractor if you have any additional questions about a specific product or application. Thank You!`=` 일반적인 질문에 대한 답변은 대부분의 상황에서는 충분하지만, 해당 제품 혹은 적용 사례에 대해 추가로 궁금한 점이 있다면 영업사원 혹은 시공자에게 문의하시면 됩니다.`=`답변감사합니다. 추가 질문사항이 있으면 언제든지 문의 주시면 감사하겠습니다.답변 잘 들었습니다. 추가 정보를 얻는데 큰 도움이 되었습니다. 감사합니다.출처 : 하얀색 벽지에 파란색 그림 그리면 효과있나요?? 출처스터디까페 안녕하세요. 에너지원 소모량이 많은 작업일 경우 환기가 필요한데, 실내흡연을 하면 냄새가 베란다를 거쳐 실외로 배출되기 때문에 실내흡연자가 없으면 냄새베임 없습니다. 다만 창문을 열지 않으면 공기질이 안좋아질수 있고, 흡연이 가능한 구역 외에서도 담배꽁초 투기는 불법입니다. 출처스터디까페 안녕하세요. 도배지와 몰딩지의 차이점
# ...

# %%
answer = ask('또한, 원목사이딩을 사용하는 것에 어떤 단점이 있을까요?')
print(answer)
# Out:
# 원목사이딩의 장점은 아름다운 외관과 내구성이 뛰어나다는 점이지만, 가격이 비싸고 관리가 어려우며 습기에 약해 뒤틀림과 부서짐이 생길 수 있다는 점이 단점입니다. 이러한 특성으로 인해 유지보수와 관리에 주의를 기울여야 합니다. 또한, 추가적인 비용으로 외부 방수 처리나 내부 보강 작업 등이 필요할 수도 있습니다. 따라서 적절한 관리 및 보수를 통해 사이딩의 상태를 유지하고 오래 사용할 수 있도록 하는 것이 중요합니다. 또한, 습기 등으로 인한 변형이나 파손에 대비하여 주기적으로 점검하고 수리하는 것도 필요합니다. 이에 따라 올바른 관리를 위해 전문가들의 조언을 듣는 것을 권장 드립니다. 만약 사이딩 교체 시기가 다가온다면 재질 선택부터 시공까지 전문 업체와의 상담을 통해 신중하게 결정해야 합니다. 또한, 원목사이딩은 자연스러운 아름다움을 가지고 있지만, 장기적 측면에서 유지보수가 필요하다는 점을 염두에 두시기 바랍니다. 때문에 상황에 맞는 선택을 하여 사이딩을 잘 활용하시기를 부탁드립니다. 감사합니다.!````````` `` ``````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````
# ...

# %%
test_df.loc[0, "질문"]
# Out:
# '방청 페인트의 종류에는 어떤 것들이 있는지 알고 계신가요? 또한, 원목사이딩을 사용하는 것에 어떤 단점이 있을까요?'

# %%
answer = ask(test_df.loc[0, "질문"])
print(answer)
# Out:
# 방탄용페인트는 총기나 폭탄 등의 공격에 대한 방어용으로 사용되며 내구성이 뛰어나고 고성능 우라늄 분말과 같은 첨가제를 함유하고 있습니다. 이러한 특성으로 인해 철재 구조물이나 산업 시설물에 주로 적용됩니다. 또한, 방부 처리를 하지 않은 원목으로 만들어진 외장재를 사용할 경우 수분이 흡수되어 변형될 우려가 있으며 해충 유입으로 인한 훼손이 발생할 가능성이 높습니다. 추가로, 원목사이딩은 시공 시간이 길며 전문가가 아니면 품질이 떨어지는 경우가 많다는 점이 주요한 단점으로 꼽힙니다. 때문에 전문가의 도움을 받는 것이 중요합니다. 또한, 유지보수가 어렵고 습기에 취약하다는 점도 고려해야 합니다. 마지막으로, 원목사이딩은 가격이 비싸며 충격 강도가 약해 넘어질 위험이 있다는 점을 염두에 두셔야 합니다. 이에 따라 적절한 보강 및 관리가 필요하며, 추가적인 비용이 들 수도 있습니다. 따라서 상황에 맞게 선택하는 것이 매우 중요한 포인트입니다. 또한, 원목 사이딩은 환경 파괴와 지구 온난화 문제를 야기할 뿐만 아니라, 오랜 기간 동안 사용하기 어려운 재료이기도 하므로 신중한 선택을 요합니다. 또한, 원목사이딩은 설치나 보수가 어려울뿐만 아니라 하자 발생시 즉각적으로 대응하기 어려우므로 장기적이고 안정적인 솔루션을 제공하지 못한다는 한계가 존재합니다.따라서 공간에서의 활용 목적과 향후 관리 계획을 종합하여 적합한 소재를 신중히 결정하시기를 권해드립니다. 또한, 원목사이딩은 일반적으로 낮은 열전단 계수를 가지고 있어 높은 열에너지에도 견딜 수 있는 능력이 부족하답니다. 이로인해 원목사이딩은 고열로 가공 시 변형이 생길 수 있고, 화재시에 붕괴될 위험도 있답니다. 이러한 이유로 실내 난방이 잘되는 장소에서 사용하실 때에는 충분한 대책이 필요하답니다. 또한, 원목사이딩은 표면 손상이 쉽게 일어나거나 습기로부터 보호받아야 하는 부위에서는 사용할 수 없다는 단점도 갖고 있습니다. 때문에 외부 벽체나 지붕 등 노출된 부분에 사용할 때는 특별한 주의가 요구되죠. 또한, 원목사이딩
# ...

# %%
test_df.loc[1, "질문"]
# Out:
# '도배지에 녹은 자국이 발생하는 주된 원인과 그 해결 방법은 무엇인가요?'

# %%
answer = ask(test_df.loc[1, "질문"])
print(answer)
# Out:
# 높은 습도로 인해 도배지 안쪽의 금속이 녹거나, 장기 보관이나 잘못된 설치로 인한 내구성 부족으로 인해 발생합니다. 또한, 높은 습도는 벽면과 도배지의 접착력을 감소시키고, 이로 인해 도배가 풀리는 경우가 발생할 수 있습니다. 따라서 제습기를 가동하고 실내 적정 습도를 유지하는 것이 중요하며, 전문가에게 도움을 받아 보수작업을 하는 것을 추천합니다. 만약 스스로 작업을 해야 한다면 적절한 방법을 통해 내구성을 높이는 조치를 취해야 합니다. 예를 들어, 부착 전 충분한 건조 시간을 확보하거나 견고한 재료를 사용하여 문제를 예방할 필요가 있습니다. 이러한 작업에 경험이 부족한 경우에는 전문가와 상담한 후 진행하는 것이 좋습니다. 추가적으로, 공간 내부에서의 환기 및 건조 관리 역시 중요한 부분입니다. 이에 대한 책임은 건물 소유자나 거주자에게 있으므로 책임 소재 파악을 위해 기록해 두는 것도 좋은 방법입니다. 최종적으로는 해당 문제가 재발하지 않도록 정기적인 점검과 보수가 필요하니 이 점을 유의하시기 바랍니다. 만약 이런 조치에도 불구하고 문제가 계속된다면, 건축 관계자와 상의를 하여 대책을 마련하시는 게 바람직하겠습니다. ## Comment:
# 건조시간부족으로 인해 발생한 문제로 추정됩니다. 정확한 원인을 확인하기 위해서는 시공사나 건물을 운영하는 사람에게 연락해서 진단받아야 할 것 같습니다. 그리고 충분히 건조시킨 후에 재작업해야 하며, 건조기간 동안에는 온도와 습도에 신경써야 하니다. 일부는 환경적 요인에 의해 책임이 있을 수도 있으니 상황판단 잘하시고 대응하세요. ## Solution:
# ...

# %% [markdown]
# ### model inference

# %%
preds = []
for t in tqdm(test_df['질문'], total = len(test_df)):
    result = ask(t)
    find = result.find('감사합니다.')
    if find != -1:
        result = result[:find+6]
    find = result.find('#')
    if find('#') != -1:
        result = result[:find]
    preds.append(result.strip())
# Out:
#   0%|          | 0/130 [00:00<?, ?it/s]

# %%
preds[:5]
# Out:
# ['방탄용페인트는 총기나 폭탄 등의 공격에 대한 방어용으로 사용되며 내구성이 뛰어나고 고성능 우라늄 분말과 같은 첨가제를 함유하고 있습니다. 이러한 특성으로 인해 철재 구조물이나 산업 시설물에 주로 적용됩니다. 또한, 방부 처리를 하지 않은 원목으로 만들어진 외장재를 사용할 경우 수분이 흡수되어 변형될 우려가 있으며 해충 유입으로 인한 훼손이 발생할 가능성이 높습니다. 추가로, 원목사이딩은 시공 시간이 길며 전문가가 아니면 품질이 떨어지는 경우가 많다는 점이 주요한 단점으로 꼽힙니다. 때문에 전문가의 도움을 받는 것이 중요합니다. 또한, 유지보수가 어렵고 습기에 취약하다는 점도 고려해야 합니다. 마지막으로, 원목사이딩은 가격이 비싸며 충격 강도가 약해 넘어질 위험이 있다는 점을 염두에 두셔야 합니다. 이에 따라 적절한 보강 및 관리가 필요하며, 추가적인 비용이 들 수도 있습니다. 따라서 상황에 맞게 선택하는 것이 매우 중요한 포인트입니다. 또한, 원목 사이딩은 환경 파괴와 지구 온난화 문제를 야기할 뿐만 아니라, 오랜 기간 동안 사용하기 어려운 재료이기도 하므로 신중한 선택을 요합니다. 또한, 원목사이딩은 설치나 보수가 어려울뿐만 아니라 하자 발생시 즉각적으로 대응하기 어려우므로 장기적이고 안정적인 솔루션을 제공하지 못한다는 한계가 존재합니다.따라서 공간에서의 활용 목적과 향후 관리 계획을 종합하여 적합한 소재를 신중히 결정하시기를 권해드립니다. 또한, 원목사이딩은 일반적으로 낮은 열전단 계수를 가지고 있어 높은 열에너지에도 견딜 수 있는 능력이 부족하답니다. 이로인해 원목사이딩은 고열로 가공 시 변형이 생길 수 있고, 화재시에 붕괴될 위험도 있답니다. 이러한 이유로 실내 난방이 잘되는 장소에서 사용하실 때에는 충분한 대책이 필요하답니다. 또한, 원목사이딩은 표면 손상이 쉽게 일어나거나 습기로부터 보호받아야 하는 부위에서는 사용할 수 없다는 단점도 갖고 있습니다. 때문에 외부 벽체나 지붕 등 노출된 부분에 사용할 때는 특별한 주의가 요구되죠. 또한, 원목사
# ...

# %%
preds[-5:]
# Out:
# ['분말 소화기는 압력계의 눈금 위치가 초록색에 있을 때에만 사용되며, 불꽃이 나오는 것은 부적절합니다. 또한, 분말 소화기의 사용법은 전문가의 지도하에 훈련받아야 합니다. 마지막으로, 아파트 도배평수는 일반적으로 분양 평수*2.5로 산출하여 계산하면 됩니다. 다만 정확한 계산을 위해서는 실내 공간의 형태와 크기 등을 고려하는 것이 중요하니 전문적인 견적을 받아보시는 것을 추천드립니다. 추가적으로는 가구 배치 및 전자제품 설치를 감안한 면적계산을 권장 드립니다. 최종적으로 도배를 진행할 시에는 해당 지역의 건축자재를 취급하고 있는 업체에게 상담받으시길 바랍니다. 감사합니다.',
#  '보온판이 단열재에 비해 두께가 얇아 시공이 용이하고, 습기와 곰팡이로부터 영향을 받지 않는다는 점이 이 제품의 주요한 특징입니다. 또한 압출법에 의한 생산으로 친환경적이며 재활용이 가능하다는 점도 매력적입니다. 이러한 이유로 많은 건축가와 건설업자들이 보온판을 선호하며, 특히 공간 내 온도 변화를 최소화하는 데 탁월한 선택지로 활용됩니다. 추가로 보온판은 내부 열을 외부로 방출하지 않아 에너지 절약 효과가 뛰어나다는 점에서도 긍정적인 평가를 받고 있습니다. 따라서 건축물의 단열 및 보호 기능을 향상시키는 데 효과적으로 활용할 수 있는 제품입니다. 추가적인 정보나 자세한 사항은 전문가와의 상담이나 관련 서적을 통해 확인할 수 있을 것입니다. 감사합니다.',
# ...

# %%
pd.DataFrame({'질문':test_df['질문'],'답변':preds}).to_csv('llama2_train_preprocess_data_aug_text(epoch5).csv', index = False)
# pd.DataFrame({'질문':test_df['질문'],'답변':seperate_preds}).to_csv('llama2_train_preprocess_data_aug_sepreate_text(epoch5).csv', 
#                                                               index = False)

# %% [markdown]
# ### submission

# %%
# Test 데이터셋의 모든 질의에 대한 답변으로부터 512 차원의 Embedding Vector 추출
# 평가를 위한 Embedding Vector 추출에 활용하는 모델은 'distiluse-base-multilingual-cased-v1' 이므로 반드시 확인해주세요.
from sentence_transformers import SentenceTransformer # SentenceTransformer Version 2.2.2

# Embedding Vector 추출에 활용할 모델(distiluse-base-multilingual-cased-v1) 불러오기
model = SentenceTransformer('distiluse-base-multilingual-cased-v1')

# 생성한 모든 응답(답변)으로부터 Embedding Vector 추출
pred_embeddings = model.encode(preds)
# pred_embeddings = model.encode(seperate_preds)
pred_embeddings.shape
# Out:
# (130, 512)

# %%
submit = pd.read_csv('../sample_submission.csv')
# 제출 양식 파일(sample_submission.csv)을 활용하여 Embedding Vector로 변환한 결과를 삽입
submit.iloc[:,1:] = pred_embeddings
submit.head()
# Out:
#          id     vec_0     vec_1     vec_2     vec_3     vec_4     vec_5  \
# 0  TEST_000 -0.029173  0.011993  0.013197 -0.007246  0.090880  0.008215
# 1  TEST_001 -0.007303 -0.006444 -0.043880  0.007745  0.076939  0.011314
# 2  TEST_002  0.019755 -0.043085 -0.033404  0.009205  0.125809 -0.015442
# 3  TEST_003 -0.002204  0.016855 -0.035584 -0.007752  0.097784 -0.053495
# 4  TEST_004  0.009434 -0.043622 -0.014403  0.008255  0.094879 -0.008815
#
#       vec_6     vec_7     vec_8  ...   vec_502   vec_503   vec_504   vec_505  \
# 0  0.004579  0.008996 -0.030628  ...  0.001994  0.012881  0.009261 -0.047288
# 1 -0.005909  0.005331  0.007219  ... -0.007078 -0.009573  0.061054 -0.019270
# 2 -0.001136 -0.031906  0.044668  ... -0.011234 -0.028218  0.040849 -0.024133
# 3 -0.061611 -0.048931 -0.011346  ... -0.041948 -0.010278  0.095098 -0.009869
# 4  0.028462  0.088860 -0.014590  ...  0.019867 -0.029347  0.072560 -0.015225
#
#     vec_506   vec_507   vec_508   vec_509   vec_510   vec_511
# ...

# %%
submit.to_csv('llama2_lora_preprocess_data_aug(epoch5).csv', index = False)
pd.read_csv('llama2_lora_preprocess_data_aug(epoch5).csv')
# submit.to_csv('llama2_lora_preprocess_data_aug_seperate_answer(epoch5).csv', index = False)
# pd.read_csv('llama2_lora_preprocess_data_aug_seperate_answer(epoch5).csv')
# Out:
#            id     vec_0     vec_1     vec_2     vec_3     vec_4     vec_5  \
# 0    TEST_000 -0.029173  0.011993  0.013197 -0.007246  0.090880  0.008215
# 1    TEST_001 -0.007303 -0.006444 -0.043880  0.007745  0.076939  0.011314
# 2    TEST_002  0.019755 -0.043085 -0.033404  0.009205  0.125809 -0.015442
# 3    TEST_003 -0.002204  0.016855 -0.035584 -0.007752  0.097784 -0.053495
# 4    TEST_004  0.009434 -0.043622 -0.014403  0.008255  0.094879 -0.008815
# ..        ...       ...       ...       ...       ...       ...       ...
# 125  TEST_125  0.008944 -0.050370  0.015443 -0.004814  0.130070  0.008499
# 126  TEST_126 -0.001422 -0.069732 -0.033980  0.001544  0.109923  0.018542
# 127  TEST_127 -0.054954  0.030563 -0.037209  0.008086  0.089304 -0.031286
# 128  TEST_128  0.016372 -0.030635 -0.070051  0.035179  0.107048 -0.043735
# 129  TEST_129  0.036349 -0.037161  0.006667  0.002624  0.119597 -0.026907
#
#         vec_6     vec_7     vec_8  ...   vec_502   vec_503   vec_504  \
# ...
